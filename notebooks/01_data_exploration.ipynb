# %% [markdown]
# # Data Exploration
# Inspect prices, returns and basic statistics.

# %%
from src.data_loader import load_config, get_historical_returns
config=load_config()
mean_returns,cov_matrix,prices=get_historical_returns(config)
prices.tail()

# %%
prices.describe()

# %%
mean_returns.sort_values(ascending=False)
